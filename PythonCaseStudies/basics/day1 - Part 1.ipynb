# %%
print("hello")
# Out:
# hello

# %% [raw]
# this is simple print function from python

# %% [markdown]
# ## Here’s a detailed guide to set up the **PATH variable** on a Windows machine for **Python** and **pip**:
#
# ### ✅ **Step 1: Install Python**
#
# 1.  Download Python from the official site: <https://www.python.org/downloads/>.
# 2.  Run the installer.
# 3.  **Important:** During installation, check the box **“Add Python to PATH”**.
#     If you missed this step, you can still add it manually (explained below).
#
#
# ### ✅ **Step 2: Locate Python Installation Path**
#
# 1.  By default, Python installs in:
#         C:\Users\<YourUsername>\AppData\Local\Programs\Python\PythonXX
#     (Replace `XX` with the version number, e.g., `Python311`).
# 2.  Inside this folder, you’ll find:
#     *   `python.exe`
#     *   `Scripts` folder (contains `pip.exe`)
#
# Paths to add:
#
#     C:\Users\<YourUsername>\AppData\Local\Programs\Python\PythonXX\
#     C:\Users\<YourUsername>\AppData\Local\Programs\Python\PythonXX\Scripts\
#
# ***
#
# ### ✅ **Step 3: Add Paths to Environment Variables**
#
# 1.  Press **Win + R**, type `sysdm.cpl`, and hit **Enter**.
# 2.  Go to **Advanced** tab → click **Environment Variables**.
# 3.  Under **System variables**, find and select **Path**, then click **Edit**.
# 4.  Click **New** and add:
#         C:\Users\<YourUsername>\AppData\Local\Programs\Python\PythonXX\
#         C:\Users\<YourUsername>\AppData\Local\Programs\Python\PythonXX\Scripts\
# 5.  Click **OK** to save.
#
# ### ✅ **Step 4: Verify Installation**
#
# 1.  Open **Command Prompt** and type:
#         python --version
#         pip --version
#     You should see the installed versions.
#
# ### ✅ **Step 5: (Optional) Use `where` Command**
#
# To confirm paths:
#
#     where python
#     where pip

# %%
vehicle_model="Mid-size sedan"
powertrain="ICE"
model_year=2025

# %%
print(vehicle_model, powertrain, model_year)
# Out:
# Mid-size sedan ICE 2025

# %%
print(f" The model is {vehicle_model}, with {powertrain}, and year is {model_year}")
# Out:
#  The model is Mid-size sedan, with ICE, and year is 2025

# %%
# constants
MAX_ENGINE_TEMP_C=105
MAX_ENGINE_RPM=6500
MIN_BATTERY_VOLTAGE=11.8

# %%
# single trip
engine_rpm=int(input("enter engine rpm "))
engine_temp_c=float(input("enter engine temp in celcius "))
vehicle_speed_kmph=78
battery_voltage=12.4
# Out:
# enter engine rpm  100
# enter engine temp in celcius  78

# %%
## health check
if engine_temp_c > MAX_ENGINE_TEMP_C:
    print("ALERT : Engine is heating")
else:
    print("Engine temperature is normal")
# Out:
# Engine temperature is normal

# %%
#multiple trips

engine_temp_readings=[88,90,92,101,98,95]
print(engine_temp_readings)
print('Maximum observed temprature ',max(engine_temp_readings))
# Out:
# [88, 90, 92, 101, 98, 95]
# Maximum observed temprature  101

# %%
# Vehicle health summary
vehicle_health={
    "max_temp":max(engine_temp_readings),
    "avg_speed":vehicle_speed_kmph,
    "battery_ok": battery_voltage > MIN_BATTERY_VOLTAGE
}

vehicle_health
# Out:
# {'max_temp': 101, 'avg_speed': 78, 'battery_ok': True}
